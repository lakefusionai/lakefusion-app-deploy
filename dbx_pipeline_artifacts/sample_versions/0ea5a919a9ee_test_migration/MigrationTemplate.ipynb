# %%
dbutils.widgets.dropdown("function", "upgrade", ["upgrade", "downgrade"], "Function")

# %%
function=dbutils.widgets.get("function")

# %%
"""
Migration: <Migration_Description>
Revision: <Migration_Revision>
"""

def upgrade():
    """
    <Migration_Description>
    """
    print(f"Applying migration: <Migration_Description>")
    print("-" * 80)
    
    print(f"Custom Upgrade Logic")
    
    print("-" * 80)
    print(f"✓ Migration applied successfully")

def downgrade():
    """
    Revert <Migration_Description>
    """
    print(f"Reverting migration: <Migration_Description>")
    print("-" * 80)
    
    print(f"Custom Downgrade Logic")
    
    print("-" * 80)
    print(f"✓ Migration reverted successfully")

# %%
if function == "downgrade":
    downgrade()
else:
    upgrade()
