# %%
# %run ../utils/execute_utils

# %%
setup_lakefusion_engine()

# %%
# Now you can safely import from the package
from lakefusion_core_engine.utils.logging_utils import get_logger

logger = get_logger(name="test_123")
logger.info("Logger initialized successfully!")
